# %% [markdown]
# # Sensitivity report (α and H bands)
#
# Run `python scripts/sensitivity_report.py` from the project root, or execute the next cell.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd()
if not (ROOT / "iav").is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from scripts.sensitivity_report import main
main()
